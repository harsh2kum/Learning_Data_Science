# %% [markdown]
# Object Oriented Programming(OOPS)

# %%
#Class is like an object constructor or blueprint for creating objects
#--create a class
class MyClass:
    x = 5

# %%
#objects
#--create object - now we can use class named MyClass to create objects
#--create an object named p1, and print the values of x
p1 = MyClass()
print(p1.x)
# Out:
# 5

# %%
#Delect Objects
del p1

# %%
#Multipe Objects 
p1 = MyClass()
p2 = MyClass()
p3 = MyClass()
print(p1.x)
print(p2.x)
print(p3.x)
# Out:
# 5
# 5
# 5

# %%
# Python __init__() Method
# All classes have a built-in method called __init__(), which is always executed when the class is being initiated.
# The __init__() method is used to assign values to object properties, or to perform operations that are necessary when the object is being created.
# why use __init__(), without __init__() method,you would need to set properties manually from each object
# Using __init__() makes it easier to create objects with initial values:  
#--create a class name Person,use the __init--() method to assign values for name and age
class Person:
    def __init__(self, name , age): # pyright: ignore[reportUnknownParameterType]
        self.name = name
        self.age = age
p1 = Person("Harsh",36)
print(p1.name)
print(p1.age)
# Out:
# Harsh
# 36

# %%
# Default values in __init__()
# you can also srt default values for parameters in the __init__() method
#--Set a default value for the age parameter:
class Person:
    def __init__(self,name,age=18):
        self.name = name
        self.age = age
        
p1 = Person("Harsh")
p2 = Person("Rohit",24)

print(p1.name,p1.age)
print(p2.name,p2.age)
# Out:
# Harsh 18
# Rohit 24

# %%
# Multiple Parameters 
# __init__() method an have as many parametrs as you need 
#---Create a Car class with multiple parametes
class Person:
    def __init__(self,name,age,city,country):
        self.name = name
        self.age = age
        self.city = city 
        self.country = country
p1 = Person("Harsh",25,"Varanasi","India")

print(p1.name)
print(p1.age)
print(p1.city)
print(p1.country)
# Out:
# Harsh
# 25
# Varanasi
# India

# %%
#Python Self Parameter is a reference to the current instance of the class
#It is used to access properties and methods that belong to the class
#--- use self to access class properties
class Person:
    def __init__(self,name,age,city):
        self.name = name
        self.age = age
        self.city = city
    
    def greet(self):
        print("Hello, my name is " + self.name)
        
p1 = Person("Harsh",25,"Varanasi")
p2 = Person("Aryan",23,"Noida")
p1.greet()
p2.greet()
# Why use Self - without self python would not know which object's properties you want to access
# Out:
# Hello, my name is Harsh
# Hello, my name is Aryan

# %%
# Self Parameter links the method to the specifc object 
class Person:
    def __init__(self,name,age):
        self.name = name 
        self.age = age
    
    def printname(self):
        print(self.name)
        print(self.age)
        
p1 = Person("Harsk",25)
p2 = Person("Arvind",30)

p1.printname()
p2.printname()
#Note:
# self Does Not Have to Be Named "self"
#It does not have to be named self, you can call it whatever you like, but it has to be the first parameter of any method in the class
# Out:
# Harsk
# 25
# Arvind
# 30

# %%
#Accessing Properties with Self 
#You can access any property of the class using self
#---Access multiple properties using self
class Car:
    def __init__(self,brand,model,year):
        self.brand = brand
        self.model = model
        self.year = year
        
    def display_info(self):
        print(f"{self.year} {self.brand} {self.model}")
car1  = Car("Toyota","Corolla",2024)
car1.display_info()
# Out:
# 2024 Toyota Corolla

# %%
# Calling Methods with self
# Call one method from another method using self:
class Person:
  def __init__(self, name):
    self.name = name

  def greet(self):
    return "Hello, " + self.name

  def welcome(self):
    message = self.greet()
    print(message + "! Welcome to our city.")
  
p1 = Person("Harsh")
p1.welcome()
p1.greet()
# Out:
# Hello, Harsh! Welcome to our city.
# 'Hello, Harsh'

# %%
#Class Properties - Properties are variables that belong to a class. They store data for each object created from the class.

#---Create a class with properties
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age
        
p1 = Person("Harsh",25)

print(p1.name)
print(p1.age)
# Out:
# Harsh
# 25

# %%
# Access Properties-- access object properties using dot notation:
class Car:
    def __init__(self,brand,model):
        self.brand = brand
        self.model = model
        
car1 = Car("BMW","Z-series")
print(car1.brand)
print(car1.model)
# Out:
# BMW
# Z-series

# %%
# Modify Properties - modify the value of properties on objects
class Person:
    def __init__(self,name,age):
        self.name = name
        self.age = age

p1 = Person("Harsh",25)
print(p1.age)

p1.age = 30
print(p1.age)
# Out:
# 25
# 30

# %%
# Delete Properties
# You can delete properties from objects using the del keyword:
#---Delete the age property:
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("Lion", 30)

del p1.age

print(p1.name) # This works
# print(p1.age) # This would cause an error
# Out:
# Lion

# %%
# Class Properties vs Object Properties
# Properties defined inside __init__() belong to each object (instance properties).
# Properties defined outside methods belong to the class itself (class properties) and are shared by all objects

class Person:
  species = "Human" # Class property

  def __init__(self, name):
    self.name = name # Instance property

p1 = Person("Emil")
p2 = Person("Tobias")

print(p1.name)
print(p2.name)
print(p1.species)
print(p2.species)
# Out:
# Emil
# Tobias
# Human
# Human

# %%
# Modifying Class Properties
# When you modify a class property, it affects all objects:
#---Change a class property:
class Person:
  lastname = ""

  def __init__(self, name):
    self.name = name

p1 = Person("Harsh")
p2 = Person("Ankir")

Person.lastname = "Gupta"

print(p1.lastname)
print(p2.lastname)
# Out:
# Gupta
# Gupta

# %%
# Add New Properties
# You can add new properties to existing objects:
#---Add a new property to an object:
class Person:
    def __init__(self,name):
        self.name = name
        
p1 = Person("Harsh")
p1.age = 25
p1.city = "Varanasi"

print(p1.name)
print(p1.age)
print(p1.city)

# Note: 
# Adding properties this way only adds them to that specific object, not to all objects of the class.
# Out:
# Harsh
# 25
# Varanasi

# %%
# Class Methods
# Methods are functions that belong to a class. They define the behavior of objects created from the class.
#--Create a method in a class:
# Note: All methods must have self as the first parameter.
class Person:
  def __init__(self, name):
    self.name = name

  def greet(self):
    print("Hello, my name is " + self.name)

p1 = Person("Emil")
p1.greet()

# %%
# Methods with Parameters
# Methods can accept parameters just like regular functions
# Create a method with parameters:
class Calculator:
  def add(self, a, b):
    return a + b

  def multiply(self, a, b):
    return a * b

calc = Calculator()
print(calc.add(5, 3))
print(calc.multiply(4, 7))
# Out:
# 8
# 28

# %%
# Methods Accessing Properties
# Methods can access and modify object properties using self:
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def get_info(self):
    return f"{self.name} is {self.age} years old"

p1 = Person("Harsh", 28)
print(p1.get_info())
# Out:
# Harsh is 28 years old

# %%
#Methods Modifying Properties
#Methods can modify the properties of an object:
#--A method that changes a property value:
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def celebrate_birthday(self):
    self.age += 1
    print(f"Happy birthday! {self.name} are now {self.age}")

p1 = Person("Harsh", 25)
p1.celebrate_birthday()
p1.celebrate_birthday()
p1.celebrate_birthday()
# Out:
# Happy birthday! Harsh are now 26
# Happy birthday! Harsh are now 27
# Happy birthday! Harsh are now 28

# %%
# __str__() Method
#The __str__() method is a special method that controls what is returned when the object is printed

#---Without the __str__() method:
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

p1 = Person("Emil", 36)
print(p1)

#---With the __str__() method:
class Person:
  def __init__(self, name, age):
    self.name = name
    self.age = age

  def __str__(self):
    return f"{self.name} ({self.age})"
p1 = Person("Harsh", 25)
print(p1)
# Out:
# ...
# Harsh (25)

# %%
# # syntax:
# # objectname = classname()
# # Object is an instance of the class
# # eg:- 
# samsung = Mobile() #samsung is object , Mobile is class
# # Tata = car()  #car is class , Tata is object

# %%
#Class is a Blueprint
# Class - contain (Data or property) and (Functions or Behavior)

#Class Basic structure
class Car:  #class Car , Color,model is object
    color = 'blue' #Data
    model = 'zxi' #Data
    def calculate_avg_speed(Km,time): #Functions or Behavior
        #some code

# %% [markdown]
# ### Banking Application -> ATM Machine

# %%
class AtmMachine:
    #Constructor (special function)
    def __init__(self):
        self.pin = ""
        self.balance = 0
        self.menu()
        
    #method
    def menu(self):
        user_input = input(  
            """                
            Hi how can i help you?
            1.Press 1 to create pin
            2.Press 2 to change pin 
            3.Press 3 to check Balance
            4.Press 4 to withdraw
            5.Anything to exit
            """
        )
        if user_input == "1":
            #create pin
            self.create_pin()
            pass
        elif user_input == "2":
            #check pin
            
            pass
        elif user_input == "3":
            #check balence
            pass
        elif user_input == "4":
            #withdraw
            pass
        else:
            exit()
def create_pin(self):
    user_pin = input("Enter your pin: ")
    self.pin = user_pin
    
    user_balance = int(input("Enter the Balance: "))
    self.balance = user_balance
    print("Pin Created Successfuly!")
    self.menu()
