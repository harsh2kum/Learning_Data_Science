# %%
# Creating Stings
s = 'hello'
s = "hello"
# multiline strings
s = '''hello'''
s = """hello"""
s = str('hello')
print(s)
# Out:
# hello

# %%
# Accessing Substrings from a String
s = 'hello world'
print(s[4])
print(s[2])
print(s[:])
print(s[-3])
print(s[6:0:-2])
print(s[-1:-6:-1])
# s[0] = 'H' # Python strings are immutable
# del s 
# del s[-1:-5:2] #'str' object does not support item deletion
print(s)
# Out:
# o
# l
# hello world
# r
# wol
# dlrow
# hello world

# %%
# Operations on Strings
# Arithmetic Operations

# Relational Operations
print('delhi' + ' ' + 'mumbai')
print('delhi'*5)
print("*"*50)
# Logical Operations
print('delhi' != 'delhi')
print('mumbai' > 'pune')
print('hello' and 'world')
print('hello' or 'world')
print('' and 'world')
print('' or 'world')
print(not 'hello')
# Loops on Strings
for i in 'delhi':
  print('pune')
  
for i in 'hello world':
    print(i)
# Membership Operations
print('D' in 'delhi')
print('h' in 'delhi')
# Out:
# delhi mumbai
# delhidelhidelhidelhidelhi
# **************************************************
# False
# False
# world
# hello
#
# world
# False
# pune
# pune
# pune
# pune
# pune
# h
# e
# l
# l
# o
#
# w
# o
# r
# l
# d
# False
# True

# %%
len('hello world')
max('hello world')
min('hello world')
sorted('hello world',reverse=True)
# Out:
# ['w', 'r', 'o', 'o', 'l', 'l', 'l', 'h', 'e', 'd', ' ']

# %%
# Capitalize/Title/Upper/Lower/Swapcase
s = 'hello world'
print(s)
print(s.capitalize())
print(s.title())
print(s.upper())
print(s.lower())
print(s.swapcase())
print('HeLlO WorLD'.swapcase())
# Out:
# hello world
# Hello world
# Hello World
# HELLO WORLD
# hello world
# HELLO WORLD
# hElLo wORld

# %%
# Count/Find/Index
'my name is Harsh'.count('i')
'my name is harsh'.find('r')
'my name is harsh'.find('x') # -1 not found
# 'my name is Harsh'.index('x')
'my name is Harsh'.index('H')
# Out:
# 11

# %%
# endswith/startswith
'hi how are you'.endswith('sd')
'hi how are you'.endswith('ou')
'my name is Harsh'.startswith('1my')
'my name is Harsh'.startswith('my')
# Out:
# True

# %%
# format
name = 'Harsh'
gender = 'male'

'Hi my name is {1} and I am a {0}'.format(gender,name)
# Out:
# 'Hi my name is Harsh and I am a male'

# %%
# isalnum/ isalpha/ isdigit/ isidentifier

'harsh1234%#'.isalnum()
'harsh'.isalpha()
'123abc'.isdigit()
'first-name'.isidentifier()
'harsh1234%#'.isalnum()
# Out:
# False

# %%
# Split/Join/Replace/strip
print('hi my name is Harsh'.split()) #convert into list
print(" ".join(['hi', 'my', 'name', 'is', 'harsh']))
print('hi my name is nitish'.replace('nitish','harsh'))
print('hi my name is nitish'.replace('nitish','Amit'))
print('harsh                           '.strip())
# Out:
# ['hi', 'my', 'name', 'is', 'Harsh']
# hi my name is harsh
# hi my name is harsh
# hi my name is Amit
# harsh

# %%
# Find the length of a given string without using the len() function
s = input('enter the string')
counter = 0
for i in s:
  counter += 1
print('length of string is',counter)
# Out:
# length of string is 5

# %%
# Extract username from a given email. 
# Eg if the email is harsh24kumar@gmail.com 
# then the username should be harsh24kumar

s = input('enter the email')
pos = s.index('@')
print(s[0:pos])
# Out:
# harsh24kumar

# %%
# Count the frequency of a particular character in a provided string. 
# Eg 'hello how are you' is the string, the frequency of h in this string is 2.

s = input('enter the email')
term = input('what would like to search for')
counter = 0
for i in s:
  if i == term:
    counter += 1
print('frequency',counter)
# Out:
# frequency 3

# %%
# Write a program which can remove a particular character from a string.
s = input('enter the string')
term = input('what would like to remove')

result = ''

for i in s:
  if i != term:
    result = result + i

print(result)
# Out:
# ars

# %%
# Write a program that can check whether a given string is palindrome or not.
# abba
# malayalam

s = input('enter the string')
flag = True
for i in range(0,len(s)//2):
  if s[i] != s[len(s) - i -1]:
    flag = False
    print('Not a Palindrome')
    break

if flag:
  print('Palindrome')
# Out:
# Palindrome

# %%
# Write a program to count the number of words in a string without split()

s = input('enter the string')
L = []
temp = ''
for i in s:

  if i != ' ':
    temp = temp + i
  else:
    L.append(temp)
    temp = ''

L.append(temp)
print(L)
# Out:
# ['sdbas']

# %%
# Write a python program to convert a string to title case without using the title()
s = input('enter the string')

L = []
for i in s.split():
  L.append(i[0].upper() + i[1:].lower())

print(" ".join(L))
# Out:
# Kdjsfb

# %%
# Write a program that can convert an integer to string.

number = int(input('enter the number'))

digits = '0123456789'
result = ''
while number != 0:
  result = digits[number % 10] + result
  number = number//10

print(result)
print(type(result))
# Out:
# 321
# <class 'str'>
