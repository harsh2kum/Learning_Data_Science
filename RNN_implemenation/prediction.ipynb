# %%
# Step 1 - Import the Libaries and Load the Model
import numpy as np
import tensorflow as tf
import tensorflow.keras.datasets import 
from tensorfow.keras.preprocessing import sequence
from tensorflow.keras.models import load_model
# Out:
#   Cell In[5], line 4
#     import tensorflow.keras.datasets import imdb
#                                      ^
# SyntaxError: invalid syntax
