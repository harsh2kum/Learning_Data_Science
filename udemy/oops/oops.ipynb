# %%
#oops 
#Class- is a blueprint for creating objects
#Creating class
class Student:
    name = "Harsh"
    place = "Hyderabad"

#Creating object(instance)
s1 = Student()
print(s1.name)
print(s1.place)
# Out:
# Harsh
# Hyderabad

# %%
# __init__ Functon 
#Constructor - All classes have function call __init__(), which is always executed when the object is begin initiated

#Create class 
class Student:
    def __init__(self,name,marks): # self parameter is a reference to the current instance of the class and is used to access variables that belongs to the class
        self.name = name  #instance attribues
        self.marks = marks
    def hello(self): #Methods - are functions that belong to objects
        print("hello",self.name)
    def get_marks(self):
        return self.marks
#creating objects
obj1 = Student("python",90)
obj1.hello() #use method
print(obj1.name,obj1.marks)

obj2 = Student("Java",49)
print(obj2.name,obj2.marks)
# Out:
# hello python
# python 90
# Java 49

# %%
class Car:
    # Class variable (shared by all instances)
    wheels = 4
    vehicle_type = "Automobile"
    
    # Constructor method
    def __init__(self, brand, color, fuel_level):
        # Instance variables (unique to each object)
        self.brand = brand
        self.color = color
        self.fuel_level = fuel_level
    
    # Instance method
    def start_engine(self):
        return f"{self.brand} engine started!"
    
    def get_info(self):
        return f"{self.color} {self.brand} with {self.fuel_level}L fuel"
    
    
# Creating objects (instances)
car1 = Car("BMW", "Red", 50)
car2 = Car("Audi", "Blue", 30)

# Accessing instance variables
print(car1.brand)        # Output: BMW
print(car2.color)        # Output: Blue

# Calling methods
print(car1.start_engine())  # Output: BMW engine started!
print(car2.get_info())      # Output: Blue Audi with 30L fuel

# Accessing class variables
print(car1.wheels)          # Output: 4
print(Car.wheels)           # Output: 4
# Out:
# BMW
# Blue
# BMW engine started!
# Blue Audi with 30L fuel
# 4
# 4

# %%
#create a student class that takes name and marks of 3 subjects as arguments in constructor,then create a method to print  the average 
class Student:
    def __init__(self,name,marks): #constructor
        self.name = name
        self.marks = marks
    
    def get_avg(self): #method
        sum = 0
        for val in self.marks:
            sum += val
        print("hello",self.name,"your avg score:",sum/3)


    
s1 = Student("Tom",[90,80,88])
s1.get_avg()

s1.name = 'pyhton'
s1.get_avg()
# Out:
# hello Tom your avg score: 86.0
# hello pyhton your avg score: 86.0

# %%
#Static Methods-method that do not use the self parameter(work at class level)
#Decorators allow us to wrap another function in order to extend the behaviour of the wrapped function,without permanently modifying it 
class Student:
    @staticmethod #Decorator
    def college():
        print("ABES College")

# %%
#Abstractoin - Hiding the implementation details of a class an only showing the essential features to the user.
#Encapsulation - Wraping data and function into a single unit(object)

# %%
#Q- Create Account class with 2 attributes- balance and account no , create methods for debit , credit and printing the balance

class Account:
    def __init__(self,bal,acc):
        self.balance = bal
        self.account_no = acc
        
    #debit
    def debit(self,amount):
        self.balance -= amount
        print("$",amount,"debited")
        print("total balance",self.get_balance())
        
    #credit
    def credit(self,amount):
        self.balance += amount
        print("$",amount,"debited")
        print("total balance",self.get_balance())
    
    #balance
    def get_balance(self):
        return self.balance

acc1 = Account(10000,5000)
acc1.debit(100)
acc1.credit(500)
# Out:
# $ 100 debited
# total balance 9900
# $ 500 debited
# total balance 10400

# %%
# del keyword - use to delete object properties or object itself
# del s3.name
# del s3

# %%
#Private attributes and methods are meant to be used only within the class and are not accessible from outside the class

# we can make it private using underscore  " __ "
#example
class Account:
    def __init__(self,acc_no,acc_password):
        self.acc_no = acc_no
        self.__acc_password = acc_password
        
    def reset_password(self):
        print(self.__acc_password)
        
acc1 = Account("283189","Ss@123")
print(acc1.acc_no)
# print(acc1.__acc_password) #it become private we canot access 
print(acc1.reset_password)
# Out:
# 283189
# <bound method Account.reset_password of <__main__.Account object at 0x0000026097664410>>

# %%
#Inheritance - when one class(or child/derived) derives the properties and methods of another class(parent/base).

#example

# class Car:
     #....
    
# class ToyotaCar(Car):

#single inheritance

class Car:
    color = "red"
    @staticmethod
    def start():
        print("car started.")
    
    @staticmethod
    def stop():
        print("car stopped")
    
class ToyotaCar(Car):
    def __init__(self,name):
        self.name = name
        
car1 = ToyotaCar("fortuner")
car2 = ToyotaCar("Hulex")

print(car1.start())
print(car1.color)
# Out:
# car started.
# None
# red

# %%
#multiple inhertitance
class car: 
    @staticmethod
    def start():
        print("car started.")
        
    @staticmethod
    def stop():
         print("car stopped")
        
class ToyotaCar(Car):
    def __init__(self,brand):
        self.brand = brand
        
class Fortuner(ToyotaCar):
    def __init__(self,type):
        self.type = type
        
car1 = Fortuner("diesel")
car1.start()
# Out:
# car started.

# %%
#Multiple Inheritance
class A:
    varA = "welcome to class A"

class B:
    varB = "welcome to class B"

class C(A,B):
    varC = "Welcome to class C"
    
c1 = C()

print(c1.varC)
print(c1.varB)
print(c1.varA)
# Out:
# Welcome to class C
# welcome to class B
# welcome to class A

# %%
#Super Method - Super() method is used to access methods of the paren class.
class Car: 
    def __init__(self, type):
        self.type = type
        
    @staticmethod
    def start():
        print("car started.")
        
    @staticmethod
    def stop():
         print("car stopped")
         
class ToyotaCar(Car):
    def __init__(self, name, type):
        self.name = name
        super().__init__(type)
        super().start()
        
car1 = ToyotaCar("prius", "electric")
print(car1.type)
# Out:
# car started.
# electric

# %%
#class method - is bound to the class and receives the class as an implicit first argument.
#Note - Static method can't access or modify class state and generally for utility.

"""
class Student:
  @classmethod  #decorator 
  def college(cls):
    pass
"""

class Person:
    name = "anonymous"
    
    @classmethod
    def changeName(cls, name):
        cls.name = name
        
p1 = Person()
p1.changeName("Harsh Kumar")
print(p1.name)    
print(Person.name)
# Out:
# Harsh Kumar
# Harsh Kumar

# %%
#Decorator-types = staticmethod,classmethod,property,getter,setter
#Property = @property decorator on any method in the class to use the method as a property.

class Student:
    def __init__(self, phy, chem, math):
        self.phy = phy
        self.math = math
        self.chem = chem
        
    @property
    def percentage(self):
        return str((self.phy + self.chem + self.math) / 3) + "%"
    
stu1 = Student(98, 97, 99)
print(stu1.percentage)

stu1.phy = 89
print(stu1.percentage)
# Out:
# 98.0%
# 95.0%

# %%
#Polymorphism : - Operator Overloading
# when the same operator is allowed to have differnt meaning according to the context.
"""
# Dunder function 
a.__add__(b)
a.__sub__(b)
a.__mul__(b)
a.__truediv__(b)
a.__mod__(b)
"""
class Complex:
    def __init__(self, real, img):
        self.real = real
        self.img = img
        
    def showNumber(self):
        print(self.real,"i +", self.img,"j")
        
    def __add__(self, num2):   #Dunder function
        newReal = self.real + num2.real
        newImg = self.img + num2.img 
        return Complex(newReal, newImg)
    
    def __sub__(self, num2):   #Dunder function
        newReal = self.real - num2.real
        newImg = self.img - num2.img 
        return Complex(newReal, newImg)
    
    
num1 = Complex(1,3)
num1.showNumber()

num2 = Complex(4,5)
num2.showNumber()

num3 = num1 + num2
num3.showNumber()

num4 = num1 - num2
num4.showNumber()
# Out:
# 1 i + 3 j
# 4 i + 5 j
# 5 i + 8 j
# -3 i + -2 j

# %%
class Circle:
    def __init__(self, radius):
        self.radius = radius
    
    def area(self):
        return (22/7) * self.radius**2
    
    def perimeter(self):
        return 2 * (22/7) * self.radius
    
c1 = Circle(21)
print(c1.area())
print(c1.perimeter())
# Out:
# 1386.0
# 132.0

# %%
class Employee:
    def __init__(self, role, dept, salary):
        self.role = role
        self.dept = dept
        self.salary = salary
        
    def showDetails(self):
        print("role =", self.role)
        print("dept =", self.dept)
        print("salary =", self.salary)
        
class Engineer(Employee):
    def __init__(self, name, age):
        self.name = name  
        self.age = age
        super().__init__("Engineer","IT","700000")
          
enginer1 = Engineer("Harsh", 24)
enginer1.showDetails()
# Out:
# role = Engineer
# dept = IT
# salary = 700000

# %%
class Order:
    def __init__(self, item, price):
        self.item = item
        self.price = price
    
    def __gt__(self,order2):  #gt is dundant function and is called greater than
        return self.price > order2.price 
           
order1 = Order("chips", 20)
order2 = Order("chai",10)

print(order1 > order2)
# Out:
# True

# %% [markdown]
# # Krish naik

# %%
#Krish naik
# A Class is a blue print for creating objects,attributes,methods
class car:
    pass

audi = car()
bmw= car()

print(type(audi))
print(audi)
print(bmw)
# Out:
# <class '__main__.car'>
# ...

# %%
#Instance variable and Methods 
class Dog:
    ## Constructor           ## it is not compalsary self ,we can write anything name,car ect
    def __init__(self,name,age): 
        self.name = name  #instance variable 
        self.age = age
        
# create  objects 
dog1 = Dog("Buddy",3)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Buddy
# 3

# %%
dog2 =Dog("janni",5)
print(dog2.name)
print(dog2.age)
# Out:
# janni
# 5

# %%
#Define a class with instance method 
class Dog:
    def __init__(self,name,age):
        self.name = name   # 'self.name' is the instance variable; 'name' is the parameter
        self.age = age
    
    def bark(self):
        print(f'{self.name} says bho')
        
dog1 = Dog("Buddy",3)
dog1.bark()
dog2 = Dog("lucy",4)
dog2.bark()
# Out:
# Buddy says bho
# lucy says bho

# %%
# self is uesd to represent the insatance of the class. It's how objectcan access their own data and methods 
#self allows that object to:
# Access its own attributes (variables)

## Modeling a Bank Account
#Define a class for bank account
class Bankaccount:
    def __init__(self,owner,balance=0):
        self.owner = owner   #->instance variable 
        self.balance= balance
        
    def deposit(self,amount):  
        self.balance+=amount  #->instance method
        print(f'{amount} is deposited. New Balance is {self.balance}')
        
    def withdraw(self,amount):
        if amount>self.balance:  
            print("insufficient Funds!")
        else:
            self.balance -= amount
            print(f'{amount} is withdrawn. New Balance is {self.balance}')
            
    def get_balance(self):
        return self.balance

#Create an account

account = Bankaccount("Harsh",5000)   
print(account.balance)
# Out:
# 5000

# %%
#call instance method
account.deposit(100)

#withdraw money

account.withdraw(300)

print(account.get_balance())
# Out:
# 100 is deposited. New Balance is 5000
# 300 is withdrawn. New Balance is 4700
# 4700

# %% [markdown]
# # Inheritance in python
#
# inheritance is a fundamental concept in oops that allows a class to inherit attributes and methods from another class.

# %%
## Inheritance (single Inheritance)
#Parent Class
class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows = windows
        self.doors = doors
        self.enginetype = enginetype
        
    def drive(self):
        print(f'The person will drive the {self.enginetype} car')
        
car1 = Car(4,5,"petrol")
car1.drive()
# Out:
# The person will drive the petrol car

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdriving):
        super().__init__(windows,doors,enginetype)
        self.is_selfdriving = is_selfdriving
    def selfdriving(self):
        print("f'Tesla supports self driving : {self.is_selfdriving}")

tesla1 = Tesla(4,5,'electric',True)
print(tesla1.selfdriving())
tesla1.drive()

# A superclass is a class whose features (methods and attributes) are inherited by another class.
# Out:
# f'Tesla supports self driving : {self.is_selfdriving}
# None
# The person will drive the electric car

# %%
#Multiple Inheritance - when a class inherits from more than one base class.

#Base Class 1
class Animal:
    def __init__(self,name):
        self.name=name
        
    def speak(self):
        print("Subclass must implemet this method")
        
#Base Class 2 
class Pet:
    def __init__(self,owner):
        self.owner = owner
        
#Derived Class 
class Dog(Animal,Pet):
    def __init__(self,name,owner):
        
        Animal.__init__(self,name)
        Pet.__init__(self,owner)
    
    def speak(self):
        return f"{self.name} say woof"
    
#create an object
dog = Dog("Buddy","Harsh")
print(dog.speak())
print(f'owner:{dog.owner}')
# Out:
# Buddy say woof
# owner:Harsh

# %% [markdown]
# Polymorphism - Polymorphism ia a core concept in oops that allows objects of different classes to be treated as a common superclass. it provide a way to perform a single action in different forms.Polymorphism is typically achieved through method overriding and interfaces

# %% [markdown]
#  Method overriding- allows a child class to provide a specific implementation of a method that ia already defined in its parent class

# %%
# Base Class 
class Animal:
    def speak(self):
        return "Sound of the animal"
    
#Derived Class 
class Dog(Animal):
    def speak(self):
        return "Woof!"
#Derived class 
class Cat(Animal):
    def speak(self):
        return "Meow"

#Function that demonstrates polymorphism
def animal_speak(animal):
    print(animal.speak())
dog = Dog()
cat = Cat()
print(dog.speak())
print(cat.speak())
animal_speak(dog)
# Out:
# Woof!
# Meow
# Woof!

# %%
# Polymorphism with Function and Methods
class Shape:
    def area(self):
        return "The area of the figure"
