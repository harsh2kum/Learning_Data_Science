# %% [markdown]
# ### Logging with Loggers
# you can create multiple loggers foe different parts of your application

# %%
import logging

# %%
# Creating a logger for module_1

logger1 = logging.getLogger('module_1')
logger1.setLevel(logging.DEBUG)

# Create a logger for module_2
logger2 = logging.getLogger('module_2')
logger2.setLevel(logging.WARNING)

# Configure logging settings
logging.basicConfig(
    level = logging.DEBUG,
    format = '%(asctime)s - %(name)s - %(levelname)s - %(message)s',
    datefmt = '%Y-%m-%d %H:%M:%S'
)

# %%
# log message with different loggers
logger1.debug("This is debug message for module_1")
logger2.warning("This is a warning message for modele_2")
logger2.error('This is an error message')
# Out:
# 2026-03-13 15:02:54 - module_1 - DEBUG - This is debug message for module_1
# 2026-03-13 15:02:54 - module_2 - WARNING - This is a warning message for modele_2
# 2026-03-13 15:02:54 - module_2 - ERROR - This is an error message
